# %%
import os
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/gradcam__ILSVRC2012_test_00001503__@breakwater@__0.513__vgg16.jpg', 'TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/gradcam__blackout_breakwater_boathouse_breakwater_84__@boathouse@__0.319__vgg19.jpg', 'TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/gradcam__lakeside-breakwater-309274393464__@lakeside@__0.364__vgg16.jpg']
labels = ['Grad-CAM - VGG19\n Prediction: breakwater', 'Grad-CAM - DeepXplore blackout\n Prediction: boathouse', 'Grad-CAM - DLFuzz\n Prediction: lakeside']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/guided_gradcam__ILSVRC2012_test_00001503__@breakwater@__0.513__vgg16.jpg', 'TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/guided_gradcam__blackout_breakwater_boathouse_breakwater_84__@boathouse@__0.319__vgg19.jpg', 'TFG/Grad-CAM/Resultats_ImageNet/ImageNet_Resultats_documentació/Resultats_imatges_memòria/guided_gradcam__lakeside-breakwater-309274393464__@lakeside@__0.364__vgg16.jpg']
labels = ['Guided Grad-CAM - VGG19\n Prediction: breakwater', 'Guided Grad-CAM - DeepXplore blackout\n Prediction: boathouse', 'Guided Grad-CAM - DLFuzz\n Prediction: lakeside']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/gradcam__05153__@Speed limit_50 km-h@__1.000__model1.jpg', 'TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/gradcam__blackout_No passing_No passing for vehicles over 3.5 metric tons_No passing for vehicles over 3.5 metric tons_68__@No passing for vehicles over 3.5 metric tons@__0.920__model2.jpg', 'TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/gradcam__05153_309728790746__@Speed limit_60 km-h@__0.818__model1.jpg']
labels = ['Grad-CAM - Model 2\n Prediction: Speed limit 50km/h', 'Grad-CAM - DeepXplore blackout\n Prediction: No passing for vehicles over 3.5 metric tons', 'Grad-CAM - DLFuzz\n Prediction: Speed limit 60km/h']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/guided_gradcam__05153__@Speed limit_50 km-h@__1.000__model1.jpg', 'TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/guided_gradcam__blackout_No passing_No passing for vehicles over 3.5 metric tons_No passing for vehicles over 3.5 metric tons_68__@No passing for vehicles over 3.5 metric tons@__0.920__model2.jpg', 'TFG/Grad-CAM/Grad-CAM_Resultats_GTSRB/Grad-CAM_GTSRB_Documentació/results_doc/guided_gradcam__05153_309728790746__@Speed limit_60 km-h@__0.818__model1.jpg']
labels = ['Guided Grad-CAM - Model 2\n Prediction: Speed limit 50km/h', 'Guided Grad-CAM - DeepXplore blackout\n Prediction: No passing for vehicles over 3.5 metric tons', 'Guided Grad-CAM - DLFuzz\n Prediction: Speed limit 60km/h']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ---

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats senyals altres/results_doc/000_XX5WM_jpg.rf.58114755bb8a3e2bc32be583fb2884e6.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/type/gradcam__000_XX5WM__@Keep left@__1.000__model2.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/type/guided_gradcam__000_XX5WM__@Keep left@__1.000__model2.jpg']
labels = ['Imatge original', 'Grad-CAM', 'Guided Grad-CAM']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.figtext(0.5, -0.05, "Model 2 Prediction: Keep Left", wrap=True, horizontalalignment='center', fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats senyals altres/results_doc/Female_Toilet_25_png.rf.b651d168b91e4f92f8798ae9f8258966.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/type/gradcam__Female_Toilet_25__@Ahead only@__0.998__model2.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/type/guided_gradcam__Female_Toilet_25__@Ahead only@__0.998__model2.jpg']
labels = ['Imatge original', 'Grad-CAM', 'Guided Grad-CAM']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.figtext(0.5, -0.05, "Model 2 Prediction: Ahead Only", wrap=True, horizontalalignment='center', fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats senyals altres/results_doc/South_Korea_road_sign_329-svg_png.rf.b766732f76b48ea74b2e6e81f304c08a.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/country/gradcam__South_Korea_road_sign_329-svg__@Roundabout mandatory@__0.944__model3.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/country/guided_gradcam__South_Korea_road_sign_329-svg__@Roundabout mandatory@__0.944__model3.jpg']
labels = ['Imatge original', 'Grad-CAM', 'Guided Grad-CAM']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.figtext(0.5, -0.05, "Model 1 Prediction: Roundabout Mandatory", wrap=True, horizontalalignment='center', fontsize=12)

plt.show()

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

image_paths = ['TFG/Grad-CAM/Resultats senyals altres/results_doc/R-1-Parada-Obrigatoria_png.rf.0fa4cc616a2969cf68f730e04afb0279.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/country/gradcam__R-1-Parada-Obrigatoria__@Stop@__0.999__model2.jpg', 'TFG/Grad-CAM/Resultats senyals altres/results_doc/country/guided_gradcam__R-1-Parada-Obrigatoria__@Stop@__0.999__model2.jpg']
labels = ['Imatge original', 'Grad-CAM', 'Guided Grad-CAM']

fig, axes = plt.subplots(1, 3, figsize=(15, 5))

for i, ax in enumerate(axes):
    img = mpimg.imread(image_paths[i])
    ax.imshow(img)
    ax.set_title(labels[i], fontsize=14)
    ax.axis('off')

plt.tight_layout()
plt.figtext(0.5, -0.05, "Model 1 Prediction: Stop", wrap=True, horizontalalignment='center', fontsize=12)
plt.show()
