# %%
# !export DATA_ROOT=/content/

# %%
# !mkdir -p $DATA_ROOT/mini-imagenet

# %%
# !tar -xzvf mini-imagenet.tar.gz -C /content/mini-imagenet
# Out:
# mini-imagenet-cache-train.pkl
# mini-imagenet-cache-val.pkl
# mini-imagenet-cache-test.pkl

# %%
# !git clone https://github.com/AhmedAyad89/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning.git
# Out:
# Cloning into 'Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning'...
# remote: Enumerating objects: 263, done.
# remote: Total 263 (delta 0), reused 0 (delta 0), pack-reused 263 (from 1)
# Receiving objects: 100% (263/263), 3.33 MiB | 23.83 MiB/s, done.
# Resolving deltas: 100% (156/156), done.

# %%
import os
# os.chdir('/content/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning')

# %%
# !pip install absl-py

# %%
# !python /content/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning_v2/run_baselines_exp.py --data_root /content/ --dataset mini-imagenet
# Out:
# 2025-04-23 14:25:51.818679: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745418351.838981   20904 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745418351.844986   20904 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745418351.860397   20904 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
# !python /content/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning_v2/run_exp.py --data_root /content/             \
                  --dataset mini-imagenet              \
                  --label_ratio 0.1        \
                  --model basic                    \
                  --results /content/results       \
                  [--disable_distractor]			 \
				  [--nshot]                          \
				  [--nclasses_train]				 \
# Out:
# 2025-04-23 15:03:35.523471: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745420615.544659   31048 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745420615.550800   31048 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1745420615.567081   31048 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# ...

# %%
import shutil

folder_path = '/content/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning_v2'

zip_file_path = 'Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning_v2.zip'

shutil.make_archive(zip_file_path, 'zip', folder_path)
# Out:
# '/content/Consitent-Prototypical-Networks-Semi-Supervised-Few-Shot-Learning_v2.zip.zip'
