# %%
# !sudo apt-get update
# !sudo apt-get install python2.7 python2.7-dev -y
# !wget https://bootstrap.pypa.io/pip/2.7/get-pip.py
# !python2.7 get-pip.py
# Out:
# Get:1 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease [3,632 B]
# Get:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  InRelease [1,581 B]
# Hit:3 http://archive.ubuntu.com/ubuntu jammy InRelease
# Get:4 http://security.ubuntu.com/ubuntu jammy-security InRelease [129 kB]
# Get:5 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ Packages [69.9 kB]
# Get:6 http://archive.ubuntu.com/ubuntu jammy-updates InRelease [128 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2204/x86_64  Packages [1,378 kB]
# Hit:8 https://ppa.launchpadcontent.net/deadsnakes/ppa/ubuntu jammy InRelease
# Hit:9 https://ppa.launchpadcontent.net/graphics-drivers/ppa/ubuntu jammy InRelease
# Get:10 https://r2u.stat.illinois.edu/ubuntu jammy InRelease [6,555 B]
# Hit:11 https://ppa.launchpadcontent.net/ubuntugis/ppa/ubuntu jammy InRelease
# Get:12 http://archive.ubuntu.com/ubuntu jammy-backports InRelease [127 kB]
# ...

# %%
# !sudo apt-get --purge remove cuda
# !sudo apt-get --purge remove nvidia-*
# !sudo apt-get autoremove
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package 'cuda' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Note, selecting 'nvidia-driver-550-server' for glob 'nvidia-*'
# Note, selecting 'nvidia-firmware-550-server-550.144.03' for glob 'nvidia-*'
# Note, selecting 'nvidia-firmware-535-535.154.05' for glob 'nvidia-*'
# Note, selecting 'nvidia-docker2' for glob 'nvidia-*'
# Note, selecting 'nvidia-firmware-560-server-560.28.03' for glob 'nvidia-*'
# Note, selecting 'nvidia-driver-570-server' for glob 'nvidia-*'
# Note, selecting 'nvidia-cuda-toolkit-doc' for glob 'nvidia-*'
# Note, selecting 'nvidia-imex' for glob 'nvidia-*'
# Note, selecting 'nvidia-dkms-450-server' for glob 'nvidia-*'
# Note, selecting 'nvidia-firmware-535-server-535.154.05' for glob 'nvidia-*'
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !sudo dpkg -i /content/TFG/Entorn/cuda-repo-ubuntu1604_8.0.61-1_amd64.deb
# !sudo apt-key adv --keyserver keyserver.ubuntu.com --recv-keys A4B469963BF863CC
# !sudo apt-key adv --keyserver keyserver.ubuntu.com --recv-keys A4B469963BF863CC
# !sudo apt-get update
# Out:
# Selecting previously unselected package cuda-repo-ubuntu1604.
# (Reading database ... 125851 files and directories currently installed.)
# Preparing to unpack .../cuda-repo-ubuntu1604_8.0.61-1_amd64.deb ...
# Unpacking cuda-repo-ubuntu1604 (8.0.61-1) ...
# Setting up cuda-repo-ubuntu1604 (8.0.61-1) ...
# ...
# Note: Check first if apt-key functionality is needed at all - it probably isn't!
# ...
# OK
# ...
# Executing: /tmp/apt-key-gpghome.SLpZ57CfHV/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys A4B469963BF863CC
# gpg: key A4B469963BF863CC: public key "cudatools <cudatools@nvidia.com>" imported
# gpg: Total number processed: 1
# gpg:               imported: 1
# ...
# Executing: /tmp/apt-key-gpghome.E3QGVFBeBT/gpg.1.sh --keyserver keyserver.ubuntu.com --recv-keys A4B469963BF863CC
# gpg: key A4B469963BF863CC: "cudatools <cudatools@nvidia.com>" not changed
# gpg: Total number processed: 1
# gpg:              unchanged: 1
# Hit:2 https://cloud.r-project.org/bin/linux/ubuntu jammy-cran40/ InRelease
# ...

# %%
# !sudo apt-get install cuda-8-0
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   cpp-12 cuda-command-line-tools-8-0 cuda-core-8-0 cuda-cublas-8-0
#   cuda-cublas-dev-8-0 cuda-cudart-8-0 cuda-cudart-dev-8-0 cuda-cufft-8-0
#   cuda-cufft-dev-8-0 cuda-curand-8-0 cuda-curand-dev-8-0 cuda-cusolver-8-0
#   cuda-cusolver-dev-8-0 cuda-cusparse-8-0 cuda-cusparse-dev-8-0
#   cuda-demo-suite-8-0 cuda-documentation-8-0 cuda-driver-dev-8-0 cuda-drivers
#   cuda-drivers-570 cuda-license-8-0 cuda-misc-headers-8-0 cuda-npp-8-0
#   cuda-npp-dev-8-0 cuda-nvgraph-8-0 cuda-nvgraph-dev-8-0 cuda-nvml-dev-8-0
#   cuda-nvrtc-8-0 cuda-nvrtc-dev-8-0 cuda-runtime-8-0 cuda-samples-8-0
#   cuda-toolkit-8-0 cuda-visual-tools-8-0 dctrl-tools default-jre
#   default-jre-headless dkms fakeroot fonts-dejavu-core fonts-dejavu-extra
#   freeglut3 freeglut3-dev gcc-12 keyboard-configuration libasan8
# ...

# %%
import os
os.environ['PATH'] = '/usr/local/cuda-8.0/bin:' + os.environ['PATH']
os.environ['CUDADIR'] = '/usr/local/cuda-8.0'
os.environ['LD_LIBRARY_PATH'] = '/usr/local/cuda-8.0/lib64:' + os.environ['LD_LIBRARY_PATH']

# %%
# !tar -xzvf /content/TFG/Entorn/cudnn-8.0-linux-x64-v6.0.tgz -C /content/
# Out:
# cuda/include/cudnn.h
# cuda/lib64/libcudnn.so
# cuda/lib64/libcudnn.so.6
# cuda/lib64/libcudnn.so.6.0.21
# cuda/lib64/libcudnn_static.a

# %%
# !sudo cp -P /content/cuda/include/cudnn.h /usr/local/cuda-8.0/include
# !sudo cp -P /content/cuda/lib64/libcudnn* /usr/local/cuda-8.0/lib64/
# !sudo chmod a+r /usr/local/cuda-8.0/lib64/libcudnn*

# %%
# !python2.7 -m pip install tensorflow-gpu==1.3.0 keras==2.0.8 pillow h5py opencv-python==3.4.1.15 pandas==0.24.2 scikit-learn==0.18.2
# Out:
# ...
#      |████████████████████████████████| 158.8 MB 56 kB/s
# ...
#      |████████████████████████████████| 276 kB 59.0 MB/s
# ...
#      |████████████████████████████████| 2.1 MB 36.0 MB/s
# ...
#      |████████████████████████████████| 2.8 MB 69.9 MB/s
# ...
#      |████████████████████████████████| 24.9 MB 1.2 MB/s
# ...
#      |████████████████████████████████| 10.1 MB 52.3 MB/s
# ...
#      |████████████████████████████████| 11.6 MB 65.9 MB/s
# ...
#      |████████████████████████████████| 1.6 MB 63.7 MB/s
# ...
#      |████████████████████████████████| 1.0 MB 69.1 MB/s
# ...
#      |████████████████████████████████| 17.0 MB 65.0 MB/s
# ...
#      |████████████████████████████████| 24.8 MB 1.3 MB/s
# ...
#      |████████████████████████████████| 574 kB 67.0 MB/s
# ...
#      |████████████████████████████████| 507 kB 60.8 MB/s
# ...
#      |████████████████████████████████| 229 kB 68.5 MB/s
# ...
#      |████████████████████████████████| 298 kB 82.1 MB/s
# ...
#      |████████████████████████████████| 87 kB 8.7 MB/s
# ...

# %%
import zipfile
with zipfile.ZipFile("/content/TFG/german_traffic_signs.zip", "r") as zip_ref:
    zip_ref.extractall("/content/gtsrb-german-traffic-sign")

# %%
import zipfile
with zipfile.ZipFile("/content/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/generated_inputs_trafficsigns_blackout0.zip", "r") as zip_ref:
    zip_ref.extractall("/content/generated_inputs_trafficsigns_blackout0")

import zipfile
with zipfile.ZipFile("/content/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/generated_inputs_trafficsigns_light0.zip", "r") as zip_ref:
    zip_ref.extractall("/content/generated_inputs_trafficsigns_light0")

import zipfile
with zipfile.ZipFile("/content/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/generated_inputs_trafficsigns_occl0.zip", "r") as zip_ref:
    zip_ref.extractall("/content/generated_inputs_trafficsigns_occl0")

# %%
import pandas as pd
import os
import glob

def find_txt_files(ending_number, initial_path=""):
    """
    Find all .txt files in the specified directory (or current directory if not given) that end with the specified number (0, 1, or 2).
    """
    search_path = os.path.join(initial_path, "*{0}.txt".format(ending_number))

    return glob.glob(search_path)

def extract_image_mappings(txt_files):
    """
    Extracts image mappings from multiple txt files.
    Returns a dictionary {original_path: [new_path1, new_path2, ...]}.
    """
    mappings = {}  # Store original -> list of new paths

    for txt_file in txt_files:
        with open(txt_file, 'r') as file:
            lines = file.readlines()

        dataset_name = txt_file.replace("TFG/DeepXplore/GTSRB/Models_LeNet/Resultats//output_", "generated_inputs_").replace(".txt", "")
        #print(dataset_name)
        i = 0
        while i < len(lines) - 2:
            #print(lines[i])
            if lines[i].startswith("Image path:") and lines[i + 1].startswith("Models predictions before:"):
                original_path = lines[i].split("Image path:")[1].strip()
                #print(original_path)
                for j in range(i + 2, len(lines)):
                    if lines[j].strip().startswith("./generated_inputs/"):
                        #print(lines[j])
                        new_path = lines[j].strip().replace("./generated_inputs", f"{dataset_name}")
                        #print(new_path)
                        if original_path in mappings:
                            mappings[original_path].append(new_path)
                        else:
                            mappings[original_path] = [new_path]
                        break
            i += 1

    return mappings

def update_dataset(csv_file, mappings, output_file, new_test_file):
    """
    Loads dataset, replaces original paths with new paths, and removes old rows.
    Returns two datasets:
    - One with the new rows.
    - One with the original dataset excluding the removed rows.
    """
    df = pd.read_csv(csv_file)

    new_rows = []
    original_paths_to_remove = set()

    for original_path, new_paths in mappings.items():
        if original_path in df["Path"].values:
            original_paths_to_remove.add(original_path)
            for new_path in new_paths:
                row = df[df["Path"] == original_path].copy()
                row["Path"] = new_path
                new_rows.append(row)

    new_rows_df = pd.concat(new_rows, ignore_index=True)
    new_rows_df.to_csv(output_file, index=False)

    test_df = df[~df["Path"].isin(original_paths_to_remove)]

    test_df.to_csv(new_test_file, index=False)

    return output_file, new_test_file

txt_files = find_txt_files(0, "/content/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats")
print("Found text files:", txt_files)

image_mappings = extract_image_mappings(txt_files)

csv_file = '/content/gtsrb-german-traffic-sign/Test.csv'
output_file = "/content/Model1_retrain_dataset.csv"
new_test_file = "/content/Model1_test_df.csv"

retrain_df, test_df = update_dataset(csv_file, image_mappings, output_file, new_test_file)
print(retrain_df)
# Out:
# Found text files: ['/content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/output_trafficsigns_occl0.txt', '/content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/output_trafficsigns_light0.txt', '/content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/output_trafficsigns_blackout0.txt']
# /content/Model1_retrain_dataset.csv

# %%
# !python2.7 /content/TFG/DeepXplore/GTSRB/Models_LeNet/retrain_model.py Model1 /content/Model1_retrain_dataset.csv /content/Model1_test_df.csv
# Out:
# Using TensorFlow backend.
# /content/drive/.shortcut-targets-by-id/1it_O7knqxkyLSnFk3XvzOWo3bxpMhh8k/TFG/Senyals_deepXplore/img_retrain
# (39860, 64, 64, 3)
# 2025-03-19 17:45:11.762913: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 17:45:11.762946: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 17:45:11.762958: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
import zipfile
import glob
import os

zip_folder = "/content/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/"

zip_files = glob.glob(os.path.join(zip_folder, "*.zip"))

for zip_file in zip_files:
    zip_name = os.path.splitext(os.path.basename(zip_file))[0]

    extract_path = os.path.join("/content", zip_name)

    with zipfile.ZipFile(zip_file, "r") as zip_ref:
        zip_ref.extractall(extract_path)

    print(f"Extracted {zip_file} to {extract_path}")
# Out:
# Extracted /content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/generated_inputs_trafficsigns_blackout2.zip to /content/generated_inputs_trafficsigns_blackout2
# Extracted /content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/generated_inputs_trafficsigns_blackout1.zip to /content/generated_inputs_trafficsigns_blackout1
# Extracted /content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/generated_inputs_trafficsigns_blackout0.zip to /content/generated_inputs_trafficsigns_blackout0
# Extracted /content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/generated_inputs_trafficsigns_light0.zip to /content/generated_inputs_trafficsigns_light0
# Extracted /content/drive/MyDrive/GIA/TFG/Senyals_deepXplore/img_retrain/generated_inputs_trafficsigns_light1.zip to /content/generated_inputs_trafficsigns_light1
# ...

# %%
import pandas as pd
import os
import glob

def find_txt_files(ending_number, initial_path=""):
    """
    Find all .txt files in the specified directory (or current directory if not given) that end with the specified number (0, 1, or 2).
    """
    search_path = os.path.join(initial_path, "*{0}.txt".format(ending_number))

    return glob.glob(search_path)

def extract_image_mappings(txt_files):
    """
    Extracts image mappings from multiple txt files.
    Returns a dictionary {original_path: [new_path1, new_path2, ...]}.
    """
    mappings = {}  # Store original -> list of new paths

    for txt_file in txt_files:
        with open(txt_file, 'r') as file:
            lines = file.readlines()

        dataset_name = txt_file.replace("TFG/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/output_", "generated_inputs_").replace(".txt", "")
        #print(dataset_name)
        i = 0
        while i < len(lines) - 2:
            #print(lines[i])
            if lines[i].startswith("Image path:") and lines[i + 1].startswith("Models predictions before:"):
                original_path = lines[i].split("Image path:")[1].strip()
                #print(original_path)
                for j in range(i + 2, len(lines)):
                    if lines[j].strip().startswith("./generated_inputs/"):
                        #print(lines[j])
                        new_path = lines[j].strip().replace("./generated_inputs", f"{dataset_name}")
                        #print(new_path)
                        if original_path in mappings:
                            mappings[original_path].append(new_path)
                        else:
                            mappings[original_path] = [new_path]
                        break
            i += 1

    return mappings

def update_dataset(csv_file, mappings, output_file, new_test_file):
    """
    Loads dataset, replaces original paths with new paths, and removes old rows.
    Returns two datasets:
    - One with the new rows.
    - One with the original dataset excluding the removed rows.
    """
    df = pd.read_csv(csv_file)

    new_rows = []
    original_paths_to_remove = set()

    for original_path, new_paths in mappings.items():
        if original_path in df["Path"].values:
            original_paths_to_remove.add(original_path)
            for new_path in new_paths:
                row = df[df["Path"] == original_path].copy()
                row["Path"] = new_path
                new_rows.append(row)

    new_rows_df = pd.concat(new_rows, ignore_index=True)
    new_rows_df.to_csv(output_file, index=False)

    test_df = df[~df["Path"].isin(original_paths_to_remove)]

    test_df.to_csv(new_test_file, index=False)

    return output_file, new_test_file

folder = "TFG/TFG/DeepXplore/GTSRB/Models_LeNet/Resultats/"

txt_files = glob.glob(os.path.join(folder, "*.txt"))

image_mappings = extract_image_mappings(txt_files)

csv_file = '/content/gtsrb-german-traffic-sign/Test.csv'
output_file = "/content/Model_tot_retrain_dataset.csv"
new_test_file = "/content/Model_tot_test_df.csv"

retrain_df, test_df = update_dataset(csv_file, image_mappings, output_file, new_test_file)
print(retrain_df)
# Out:
# /content/Model_tot_retrain_dataset.csv

# %%
# !python2.7 /content/TFG/DeepXplore/GTSRB/Models_LeNet/retrain_model.py Model1 /content/Model_tot_retrain_dataset.csv /content/Model_tot_test_df.csv
# Out:
# Using TensorFlow backend.
# /content/drive/.shortcut-targets-by-id/1it_O7knqxkyLSnFk3XvzOWo3bxpMhh8k/TFG/Senyals_deepXplore/img_retrain
# (41201, 64, 64, 3)
# 2025-03-19 18:05:29.599183: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:05:29.599237: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:05:29.599251: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python2.7 /content/TFG/DeepXplore/GTSRB/Models_LeNet/retrain_model.py Model2 /content/Model_tot_retrain_dataset.csv /content/Model_tot_test_df.csv
# Out:
# Using TensorFlow backend.
# (41201, 64, 64, 3)
# 2025-03-19 18:06:33.938401: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:06:33.938439: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:06:33.938452: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:06:33.938461: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...

# %%
# !python2.7 /content/TFG/DeepXplore/GTSRB/Models_LeNet/retrain_model.py Model3 /content/Model_tot_retrain_dataset.csv /content/Model_tot_test_df.csv
# Out:
# Using TensorFlow backend.
# (41201, 64, 64, 3)
# 2025-03-19 18:07:44.494083: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.1 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:07:44.494124: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:07:44.494135: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2025-03-19 18:07:44.494144: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# ...
